# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from tabulate import tabulate
import time
import os
from IPython.display import clear_output
from platform   import system as system_name  # Returns the system/OS name
from subprocess import call   as system_call  # Execute a shell command

# %%
#create new browser
driver = webdriver.Chrome(executable_path='./chromedriver')
# Out:
# /var/folders/yg/850wklzd0235d_m3lywy8trh0000gn/T/ipykernel_9671/3172748440.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='./chromedriver')

# %%
driver.get('https://app.drift.trade/?authority=2LtdXY347HxPdwGivppJVyd3QXgnkpNGjmbKwRZ22VHj')

# %%
time.sleep(5)
classes = driver.find_elements_by_class_name('overflow-x-hidden')
direction = classes[2].find_elements_by_class_name('capitalize')
token= classes[2].find_elements_by_class_name('font-numeral')
print(direction)
# Out:
# /var/folders/yg/850wklzd0235d_m3lywy8trh0000gn/T/ipykernel_9671/429286723.py:2: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   classes = driver.find_elements_by_class_name('overflow-x-hidden')
# [<selenium.webdriver.remote.webelement.WebElement (session="17438c51664aaf37f17fc7427ebbb6d0", element="def3ff08-f7b6-41a7-9c3a-9e9bb4f706ca")>, <selenium.webdriver.remote.webelement.WebElement (session="17438c51664aaf37f17fc7427ebbb6d0", element="c6bb16f5-6e6e-47b6-8cc2-5fca389df38c")>, <selenium.webdriver.remote.webelement.WebElement (session="17438c51664aaf37f17fc7427ebbb6d0", element="98c0ba6d-e37c-4077-8434-a0363652980d")>, <selenium.webdriver.remote.webelement.WebElement (session="17438c51664aaf37f17fc7427ebbb6d0", element="1966bac7-b003-42f3-acb3-e8fda4df20be")>, <selenium.webdriver.remote.webelement.WebElement (session="17438c51664aaf37f17fc7427ebbb6d0", element="61a16113-c447-4a8b-8c43-9d43c71d072e")>]
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:464: UserWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   warnings.warn("find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead")

# %%
for i in range(len(direction)):
    print(direction[i].text)
# Out:
# Long
# Long
# Long
# Short
# Short

# %%
def clear_screen():
    system_call('clear')

# %%
head = ["MARKET", "SIZE", "NOTIONAL", "ENTRY PRICE", "EST. EXIT PRICE","EST. LIQ PRICE", "p&l"]
val=list()
entry=list()
for i in range(100):
    time.sleep(3)
    classes = driver.find_elements_by_class_name('overflow-x-hidden')
    direction = classes[2].find_elements_by_class_name('capitalize')
    token= classes[2].find_elements_by_class_name('font-numeral')
    for i in range(len(token)):
        if(len(entry)==7):
            val.append(entry)
            entry=[]
        entry.append(token[i].text)
    # os.system('clear')
    clear_screen()
    clear_output(wait=True)
    print(tabulate(val, headers=head, tablefmt="grid"))
    val=[]
# Out:
# +-----------+--------------+---------------+---------------+-------------------+------------------+-------------+
# | MARKET    | SIZE         | NOTIONAL      | ENTRY PRICE   | EST. EXIT PRICE   | EST. LIQ PRICE   | p&l         |
# +===========+==============+===============+===============+===================+==================+=============+
# | BTC-PERP  | 1.4762 BTC   | $68,805.70    | $39,770.4     | $46,610.0         | $378,009         | -$10,096.70 |
# +-----------+--------------+---------------+---------------+-------------------+------------------+-------------+
# | LUNA-PERP | 10,226 LUNA  | $1,131,553.93 | $98.3398      | $110.649          | $61.8069         | $125,882.93 |
# +-----------+--------------+---------------+---------------+-------------------+------------------+-------------+
# | AVAX-PERP | 2,040.9 AVAX | $200,999.38   | $94.5879      | $98.4857          | None             | $7,955.01   |
# +-----------+--------------+---------------+---------------+-------------------+------------------+-------------+
# | ADA-PERP  | 132,050 ADA  | $151,782.75   | $1.19979      | $1.14946          | None             | -$6,646.03  |
# +-----------+--------------+---------------+---------------+-------------------+------------------+-------------+
# | BNB-PERP  | 157.57 BNB   | $70,307.51    | $414.765      | $446.190          | $3,550.17        | -$4,951.74  |
# +-----------+--------------+---------------+---------------+-------------------+------------------+-------------+
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [332], in <cell line: 4>()
#       3 entry=list()
#       4 for i in range(100):
# ----> 5     time.sleep(3)
#       6     classes = driver.find_elements_by_class_name('overflow-x-hidden')
#       7     direction = classes[2].find_elements_by_class_name('capitalize')
#
# KeyboardInterrupt:
