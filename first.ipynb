# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from tabulate import tabulate
import time
import os
from IPython.display import clear_output
from platform   import system as system_name  # Returns the system/OS name
from subprocess import call   as system_call  # Execute a shell command
import csv
import numpy as np
import pandas as pd
import datetime

# %%
#create new browser
driver = webdriver.Chrome(executable_path='./chromedriver')
# Out:
# /var/folders/yg/850wklzd0235d_m3lywy8trh0000gn/T/ipykernel_25242/3172748440.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='./chromedriver')

# %%
driver.get('https://app.drift.trade/portfolio?authority=AAw935winL5j5mVyWqSYiGkue52S9BHpRPwX7DUhQxyr')

# %%
def clear_screen():
    system_call('clear')

# %%
time.sleep(15)
driver.find_element(by=By.XPATH, value='//*[@id="userInfo"]/div/div/div[1]/div/div[3]/button').click()
head = ["MARKET", "DIRECTION" ,"Size", "ENTRY PRICE", "EST. EXIT PRICE" ]
val=list()
entry=list()
while(1):
    time.sleep(1)
    # classes = driver.find_element(by = By.XPATH, value= '//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div/div[8]/span[1]')
    direction = driver.find_element(by = By.XPATH, value= '//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div[1]/div[2]').text
    token= driver.find_element(by = By.XPATH, value='//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div[1]/div[1]').text
    size=driver.find_element(by = By.XPATH, value='//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div[1]/div[3]').text
    entryPrice= driver.find_element(by = By.XPATH, value='//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div[1]/div[5]').text
    notion=driver.find_element(by = By.XPATH, value='//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div[1]/div[4]').text
    entry=[]
    entry.append(datetime.datetime.now())
    entry.append(token)
    entry.append(direction)
    entry.append(size)
    entry.append(notion)
    entry.append(entryPrice)
    table = pd.DataFrame(val,columns=["TIME","MARKET", "DIRECTION" ,"Size","NOTIONAL", "ENTRYPRICE"])
    if(table.shape[0]== 0 or table.iloc[int(table.shape[0])-1].MARKET!=token or table.iloc[int(table.shape[0])-1].DIRECTION!=direction or table.iloc[int(table.shape[0])-1].Size!=size or table.iloc[int(table.shape[0])-1].ENTRYPRICE!=entryPrice or table.iloc[int(table.shape[0])-1].NOTIONAL!=notion):
        time.sleep(2)
        val.append(entry)
        filename= "market.csv"
        clear_screen()
        clear_output(wait=True)
        table.append(entry)
        print(table)
        table.to_csv('file1.csv')
# Out:
#                         TIME    MARKET DIRECTION        Size   NOTIONAL  \
# 0 2022-05-04 23:23:56.130905  SOL-PERP     Short  3.5365 SOL    $307.91
# 1 2022-05-04 23:27:37.202169  SOL-PERP      Long  15.667 SOL  $1,367.43
# 2 2022-05-04 23:28:23.913905  SOL-PERP      Long  3.1997 SOL    $279.38
# 3 2022-05-04 23:28:33.440999  SOL-PERP      Long  13.490 SOL  $1,175.55
#
#   ENTRYPRICE
# 0   $87.0657
# 1   $87.2802
# 2   $87.3157
# 3   $87.1449
# /var/folders/yg/850wklzd0235d_m3lywy8trh0000gn/T/ipykernel_25242/2748488767.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table.append(entry)
