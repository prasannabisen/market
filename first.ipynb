# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from tabulate import tabulate
import time
import os
from IPython.display import clear_output
from platform   import system as system_name  # Returns the system/OS name
from subprocess import call   as system_call  # Execute a shell command

# %%
#create new browser
driver = webdriver.Chrome(executable_path='./chromedriver')
# Out:
# /var/folders/yg/850wklzd0235d_m3lywy8trh0000gn/T/ipykernel_13795/3172748440.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='./chromedriver')

# %%
driver.get('https://app.drift.trade/portfolio?authority=AAw935winL5j5mVyWqSYiGkue52S9BHpRPwX7DUhQxyr')

# %%
time.sleep(1)
classes = driver.find_element(by = By.XPATH, value= '//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div/div[8]/span[1]')
Direction = driver.find_element(by = By.XPATH, value= '//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div/div[2]')
# direction = classes[2].find_elements_by_class_name('capitalize')')
# token= classes[2].find_elements_by_class_name('font-numeral')
print(classes.text)
print(Direction.text)
# Out:
# -$59.02
# Short

# %%
for i in range(len(direction)):
    print(direction[i].text)

# %%
def clear_screen():
    system_call('clear')

# %%
head = ["MARKET", "SIZE", "NOTIONAL", "ENTRY PRICE", "EST. EXIT PRICE","EST. LIQ PRICE", "p&l"]
val=list()
entry=list()
for i in range(100):
    time.sleep(3)
    classes = driver.find_elements_by_class_name('overflow-x-hidden')
    direction = classes[2].find_elements_by_class_name('capitalize')
    token= classes[2].find_elements_by_class_name('font-numeral')
    for i in range(len(token)):
        if(len(entry)==7):
            val.append(entry)
            entry=[]
        entry.append(token[i].text)
    # os.system('clear')
    clear_screen()
    clear_output(wait=True)
    print(tabulate(val, headers=head, tablefmt="grid"))
    val=[]
# Out:
# +----------+--------+------------+---------------+-------------------+------------------+-------+
# | MARKET   | SIZE   | NOTIONAL   | ENTRY PRICE   | EST. EXIT PRICE   | EST. LIQ PRICE   | p&l   |
# +==========+========+============+===============+===================+==================+=======+
# +----------+--------+------------+---------------+-------------------+------------------+-------+
