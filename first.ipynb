# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from tabulate import tabulate
import time
import os
from IPython.display import clear_output
from platform   import system as system_name  # Returns the system/OS name
from subprocess import call   as system_call  # Execute a shell command
import csv
import numpy as np
import pandas as pd
import datetime

# %%
#create new browser
driver = webdriver.Chrome(executable_path='./chromedriver')
# Out:
# /var/folders/yg/850wklzd0235d_m3lywy8trh0000gn/T/ipykernel_14927/3172748440.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='./chromedriver')

# %%
driver.get('https://app.drift.trade/portfolio?authority=AAw935winL5j5mVyWqSYiGkue52S9BHpRPwX7DUhQxyr')

# %%
def clear_screen():
    system_call('clear')

# %%
time.sleep(15)
head = ["MARKET", "DIRECTION" ,"p&l", "ENTRY PRICE", "EST. EXIT PRICE" ]
val=list()
entry=list()
while(1):
    time.sleep(2)
    # classes = driver.find_element(by = By.XPATH, value= '//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div/div[8]/span[1]')
    direction = driver.find_element(by = By.XPATH, value= '//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div/div[2]').text
    token= driver.find_element(by = By.XPATH, value='//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div/div[1]/button').text
    pl=driver.find_element(by = By.XPATH, value='//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div/div[8]/span[1]').text
    entryPrice= driver.find_element(by = By.XPATH, value='//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div/div[6]/button').text
    entry=[]
    entry.append(datetime.datetime.now())
    entry.append(token)
    entry.append(direction)
    entry.append(pl)
    entry.append(entryPrice)
    table = pd.DataFrame(val,columns=["TIME","MARKET", "DIRECTION" ,"pl", "ENTRYPRICE"])
    if(table.shape[0]== 0 or table.iloc[int(table.shape[0])-1].MARKET!=token or table.iloc[int(table.shape[0])-1].DIRECTION!=direction or table.iloc[int(table.shape[0])-1].pl!=pl or table.iloc[int(table.shape[0])-1].ENTRYPRICE!=entryPrice):
        time.sleep(2)
        val.append(entry)
        filename= "market.csv"
        clear_screen()
        clear_output(wait=True)
        table.append(entry)
        print(table)
        table.to_csv('file1.csv')
# Out:
#                         TIME    MARKET DIRECTION       pl ENTRYPRICE
# 0 2022-04-25 23:40:22.791026  SOL-PERP      Long  $257.12   $98.7662
# 1 2022-04-25 23:41:38.523339  SOL-PERP      Long  $255.09   $98.7654
# 2 2022-04-25 23:41:44.619449  SOL-PERP      Long  $244.50   $98.7616
# 3 2022-04-25 23:41:48.690947  SOL-PERP      Long  $241.50   $98.7606
# 4 2022-04-25 23:42:05.098125  SOL-PERP      Long  $227.32   $98.7554
# 5 2022-04-25 23:42:17.475148  SOL-PERP      Long  $215.99   $98.7513
# /var/folders/yg/850wklzd0235d_m3lywy8trh0000gn/T/ipykernel_14927/4155188324.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table.append(entry)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/prasannabisen/Desktop/python/Untitled Folder/first.ipynb Cell 5' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/prasannabisen/Desktop/python/Untitled%20Folder/first.ipynb#ch0000004?line=3'>4</a> entry=list()
#       <a href='vscode-notebook-cell:/Users/prasannabisen/Desktop/python/Untitled%20Folder/first.ipynb#ch0000004?line=4'>5</a> while(1):
# ----> <a href='vscode-notebook-cell:/Users/prasannabisen/Desktop/python/Untitled%20Folder/first.ipynb#ch0000004?line=5'>6</a>     time.sleep(2)
#       <a href='vscode-notebook-cell:/Users/prasannabisen/Desktop/python/Untitled%20Folder/first.ipynb#ch0000004?line=6'>7</a>     # classes = driver.find_element(by = By.XPATH, value= '//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div/div[8]/span[1]')
#       <a href='vscode-notebook-cell:/Users/prasannabisen/Desktop/python/Untitled%20Folder/first.ipynb#ch0000004?line=7'>8</a>     direction = driver.find_element(by = By.XPATH, value= '//*[@id="userInfo"]/div/div/div[2]/div/div/div/div/div[2]/div/div/div/div[2]').text
#
# KeyboardInterrupt:
